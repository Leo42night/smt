# %% [markdown]
# Contoh Cara split dataset jadi korpus terpisah

# %%
import pandas
df = pandas.read_csv('indo-sambas.csv')
df.head()
# Out:
#                                            indonesia  \
# 0    Kalimat-kalimat tersebut adalah sebagai berikut
# 1  Manusia membutuhkan makanan dan air supaya men...
# 2  Tanaman hijau menggunakan air untuk membuat ma...
# 3  Tanaman yang tidak mendapat air akan layu dan ...
# 4  Keberhasilan belajar murid tidak hanya bergant...
#
#                                        melayu_sambas
# 0         Kalimat-kalimat iye adelah sebogoi berikot
# 1  manusie perlu makan dan aek agor jodi kuat dan...
# 2    tanaman ijau ngunekan aek untok buot makanannye
# 3  tanaman yang daan dopat aek akan layok dan jod...
# 4  keberhaselan belojor murid daan hanye tergantu...

# %%
df['indonesia'].to_csv('corpus/korpus.id', sep='\n', index=False)
df['melayu_sambas'].to_csv('corpus/korpus.smb', sep='\n', index=False)
